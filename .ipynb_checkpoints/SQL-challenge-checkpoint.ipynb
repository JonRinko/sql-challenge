# %% [markdown]
# <img src="img/sql.png" width = 200, height = 200, align = "right">

# %% [markdown]
# # SQL Challenge

# %% [markdown]
# ### Jon Rinko

# %%
# pandas 
import pandas as pd

# %%
# let's load sql to use it in jupyter 
# %load_ext sql
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
# %sql sqlite://
# Out:
# 'Connected: @None'

# %%
# %%sql
# CREATE TABLE departments(
# dept_no varchar(100),
# dept_name varchar(100));
# Out:
#  * sqlite://
# Done.
# []
